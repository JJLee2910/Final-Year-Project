# %%
import pickle
import matplotlib.pyplot as plt

# %%
# Load the history object
with open('emotion_model_history.pkl', 'rb') as f:
    history = pickle.load(f)

# %%
# Plot the training and validation loss
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history['loss'], label='Training Loss')
plt.plot(history['val_loss'], label='Validation Loss')
plt.title('Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

# Plot the training and validation accuracy
plt.subplot(1, 2, 2)
plt.plot(history['accuracy'], label='Training Accuracy')
plt.plot(history['val_accuracy'], label='Validation Accuracy')
plt.title('Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()

# %%
# import required packages
import cv2
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Dense, Dropout, Flatten
from keras.optimizers import Adam
from keras.preprocessing.image import ImageDataGenerator
import pickle

# Initialize image data generator with rescaling
train_data_gen = ImageDataGenerator(rescale=1./255)
validation_data_gen = ImageDataGenerator(rescale=1./255)

# Preprocess all train images
train_generator = train_data_gen.flow_from_directory(
        'data/train',
        target_size=(48, 48),
        batch_size=64,
        color_mode="grayscale",
        class_mode='categorical')

# Preprocess all test images
validation_generator = validation_data_gen.flow_from_directory(
        'data/test',
        target_size=(48, 48),
        batch_size=64,
        color_mode="grayscale",
        class_mode='categorical')

# create model structure
emotion_model = Sequential()

emotion_model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=(48, 48, 1)))
emotion_model.add(Conv2D(64, kernel_size=(3, 3), activation='relu'))
emotion_model.add(MaxPooling2D(pool_size=(2, 2)))
emotion_model.add(Dropout(0.25))

emotion_model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
emotion_model.add(MaxPooling2D(pool_size=(2, 2)))
emotion_model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
emotion_model.add(MaxPooling2D(pool_size=(2, 2)))
emotion_model.add(Dropout(0.25))

emotion_model.add(Flatten())
emotion_model.add(Dense(1024, activation='relu'))
emotion_model.add(Dropout(0.5))
emotion_model.add(Dense(7, activation='softmax'))

cv2.ocl.setUseOpenCL(False)
optimizer = Adam(learning_rate=0.0001)
emotion_model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])

# Train the neural network/model
emotion_model_info = emotion_model.fit_generator(
        train_generator,
        steps_per_epoch=28709 // 64,
        epochs=50,
        validation_data=validation_generator,
        validation_steps=7178 // 64)
# Out:
# WARNING:tensorflow:From c:\Users\JJ\anaconda3\envs\JJ\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# Found 28709 images belonging to 7 classes.
# Found 7178 images belonging to 7 classes.
# WARNING:tensorflow:From c:\Users\JJ\anaconda3\envs\JJ\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From c:\Users\JJ\anaconda3\envs\JJ\Lib\site-packages\keras\src\layers\pooling\max_pooling2d.py:161: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# Epoch 1/50
# C:\Users\JJ\AppData\Local\Temp\ipykernel_25012\895111125.py:53: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   emotion_model_info = emotion_model.fit_generator(
# WARNING:tensorflow:From c:\Users\JJ\anaconda3\envs\JJ\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From c:\Users\JJ\anaconda3\envs\JJ\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 448/448 [==============================] - 54s 117ms/step - loss: 1.8015 - accuracy: 0.2601 - val_loss: 1.7111 - val_accuracy: 0.3415
# Epoch 2/50
# 448/448 [==============================] - 51s 113ms/step - loss: 1.6242 - accuracy: 0.3638 - val_loss: 1.5413 - val_accuracy: 0.4153
# Epoch 3/50
# 448/448 [==============================] - 50s 112ms/step - loss: 1.5183 - accuracy: 0.4130 - val_loss: 1.4487 - val_accuracy: 0.4513
# Epoch 4/50
# 448/448 [==============================] - 51s 114ms/step - loss: 1.4511 - accuracy: 0.4430 - val_loss: 1.3905 - val_accuracy: 0.4750
# Epoch 5/50
# 448/448 [==============================] - 50s 113ms/step - loss: 1.3878 - accuracy: 0.4717 - val_loss: 1.3453 - val_accuracy: 0.4876
# Epoch 6/50
# 448/448 [==============================] - 51s 114ms/step - loss: 1.3361 - accuracy: 0.4927 - val_loss: 1.2998 - val_accuracy: 0.5100
# Epoch 7/50
# 448/448 [==============================] - 50s 112ms/step - loss: 1.2928 - accuracy: 0.5100 - val_loss: 1.2671 - val_accuracy: 0.5173
# Epoch 8/50
# 448/448 [==============================] - 50s 112ms/step - loss: 1.2554 - accuracy: 0.5277 - val_loss: 1.2459 - val_accuracy: 0.5229
# Epoch 9/50
# 448/448 [==============================] - 50s 112ms/step - loss: 1.2158 - accuracy: 0.5431 - val_loss: 1.2251 - val_accuracy: 0.5326
# Epoch 10/50
# 448/448 [==============================] - 50s 112ms/step - loss: 1.1873 - accuracy: 0.5549 - val_loss: 1.1994 - val_accuracy: 0.5392
# Epoch 11/50
# 448/448 [==============================] - 50s 112ms/step - loss: 1.1588 - accuracy: 0.5638 - val_loss: 1.1722 - val_accuracy: 0.5534
# Epoch 12/50
# 448/448 [==============================] - 50s 112ms/step - loss: 1.1338 - accuracy: 0.5774 - val_loss: 1.1599 - val_accuracy: 0.5579
# Epoch 13/50
# 448/448 [==============================] - 51s 113ms/step - loss: 1.1076 - accuracy: 0.5847 - val_loss: 1.1496 - val_accuracy: 0.5587
# Epoch 14/50
# 448/448 [==============================] - 51s 113ms/step - loss: 1.0820 - accuracy: 0.5956 - val_loss: 1.1349 - val_accuracy: 0.5679
# Epoch 15/50
# 448/448 [==============================] - 50s 112ms/step - loss: 1.0575 - accuracy: 0.6080 - val_loss: 1.1204 - val_accuracy: 0.5783
# Epoch 16/50
# 448/448 [==============================] - 50s 113ms/step - loss: 1.0313 - accuracy: 0.6180 - val_loss: 1.1158 - val_accuracy: 0.5827
# Epoch 17/50
# 448/448 [==============================] - 50s 112ms/step - loss: 1.0115 - accuracy: 0.6246 - val_loss: 1.1135 - val_accuracy: 0.5778
# Epoch 18/50
# 448/448 [==============================] - 50s 112ms/step - loss: 0.9879 - accuracy: 0.6331 - val_loss: 1.1038 - val_accuracy: 0.5878
# Epoch 19/50
# 448/448 [==============================] - 50s 112ms/step - loss: 0.9628 - accuracy: 0.6424 - val_loss: 1.1043 - val_accuracy: 0.5850
# Epoch 20/50
# 448/448 [==============================] - 51s 114ms/step - loss: 0.9433 - accuracy: 0.6531 - val_loss: 1.0935 - val_accuracy: 0.5884
# Epoch 21/50
# 448/448 [==============================] - 51s 114ms/step - loss: 0.9197 - accuracy: 0.6597 - val_loss: 1.0869 - val_accuracy: 0.5932
# Epoch 22/50
# 448/448 [==============================] - 51s 114ms/step - loss: 0.8958 - accuracy: 0.6674 - val_loss: 1.0763 - val_accuracy: 0.5986
# Epoch 23/50
# 448/448 [==============================] - 51s 114ms/step - loss: 0.8712 - accuracy: 0.6782 - val_loss: 1.0892 - val_accuracy: 0.5972
# Epoch 24/50
# 448/448 [==============================] - 50s 112ms/step - loss: 0.8509 - accuracy: 0.6883 - val_loss: 1.0846 - val_accuracy: 0.5996
# Epoch 25/50
# 448/448 [==============================] - 50s 112ms/step - loss: 0.8281 - accuracy: 0.6954 - val_loss: 1.0802 - val_accuracy: 0.6009
# Epoch 26/50
# 448/448 [==============================] - 50s 112ms/step - loss: 0.8048 - accuracy: 0.7027 - val_loss: 1.0739 - val_accuracy: 0.6024
# Epoch 27/50
# 448/448 [==============================] - 52s 115ms/step - loss: 0.7842 - accuracy: 0.7136 - val_loss: 1.0824 - val_accuracy: 0.6056
# Epoch 28/50
# 448/448 [==============================] - 50s 112ms/step - loss: 0.7587 - accuracy: 0.7245 - val_loss: 1.0721 - val_accuracy: 0.6094
# Epoch 29/50
# 448/448 [==============================] - 51s 114ms/step - loss: 0.7381 - accuracy: 0.7318 - val_loss: 1.0932 - val_accuracy: 0.6067
# Epoch 30/50
# 448/448 [==============================] - 50s 113ms/step - loss: 0.7152 - accuracy: 0.7389 - val_loss: 1.0904 - val_accuracy: 0.6059
# Epoch 31/50
# 448/448 [==============================] - 50s 112ms/step - loss: 0.6947 - accuracy: 0.7482 - val_loss: 1.1076 - val_accuracy: 0.6059
# Epoch 32/50
# 448/448 [==============================] - 50s 112ms/step - loss: 0.6674 - accuracy: 0.7576 - val_loss: 1.0943 - val_accuracy: 0.6154
# Epoch 33/50
# 448/448 [==============================] - 50s 112ms/step - loss: 0.6511 - accuracy: 0.7617 - val_loss: 1.0825 - val_accuracy: 0.6099
# Epoch 34/50
# 448/448 [==============================] - 50s 112ms/step - loss: 0.6295 - accuracy: 0.7706 - val_loss: 1.1102 - val_accuracy: 0.6120
# Epoch 35/50
# 448/448 [==============================] - 51s 113ms/step - loss: 0.6133 - accuracy: 0.7774 - val_loss: 1.0899 - val_accuracy: 0.6190
# Epoch 36/50
# 448/448 [==============================] - 51s 114ms/step - loss: 0.5963 - accuracy: 0.7834 - val_loss: 1.1086 - val_accuracy: 0.6186
# Epoch 37/50
# 448/448 [==============================] - 53s 118ms/step - loss: 0.5707 - accuracy: 0.7944 - val_loss: 1.1200 - val_accuracy: 0.6162
# Epoch 38/50
# 448/448 [==============================] - 52s 117ms/step - loss: 0.5486 - accuracy: 0.8010 - val_loss: 1.1162 - val_accuracy: 0.6189
# Epoch 39/50
# 448/448 [==============================] - 53s 118ms/step - loss: 0.5449 - accuracy: 0.8028 - val_loss: 1.1326 - val_accuracy: 0.6166
# Epoch 40/50
# 448/448 [==============================] - 53s 119ms/step - loss: 0.5174 - accuracy: 0.8125 - val_loss: 1.1424 - val_accuracy: 0.6134
# Epoch 41/50
# 448/448 [==============================] - 53s 119ms/step - loss: 0.5093 - accuracy: 0.8157 - val_loss: 1.1424 - val_accuracy: 0.6198
# Epoch 42/50
# 448/448 [==============================] - 53s 119ms/step - loss: 0.4827 - accuracy: 0.8269 - val_loss: 1.1590 - val_accuracy: 0.6203
# Epoch 43/50
# 448/448 [==============================] - 53s 119ms/step - loss: 0.4683 - accuracy: 0.8309 - val_loss: 1.1750 - val_accuracy: 0.6161
# Epoch 44/50
# 448/448 [==============================] - 53s 119ms/step - loss: 0.4586 - accuracy: 0.8334 - val_loss: 1.1721 - val_accuracy: 0.6172
# Epoch 45/50
# 448/448 [==============================] - 53s 119ms/step - loss: 0.4407 - accuracy: 0.8407 - val_loss: 1.2002 - val_accuracy: 0.6175
# Epoch 46/50
# 448/448 [==============================] - 53s 117ms/step - loss: 0.4264 - accuracy: 0.8479 - val_loss: 1.1881 - val_accuracy: 0.6207
# Epoch 47/50
# 448/448 [==============================] - 52s 117ms/step - loss: 0.4112 - accuracy: 0.8512 - val_loss: 1.1905 - val_accuracy: 0.6226
# Epoch 48/50
# 448/448 [==============================] - 53s 118ms/step - loss: 0.4002 - accuracy: 0.8567 - val_loss: 1.2022 - val_accuracy: 0.6243
# Epoch 49/50
# 448/448 [==============================] - 52s 117ms/step - loss: 0.3887 - accuracy: 0.8601 - val_loss: 1.2460 - val_accuracy: 0.6170
# Epoch 50/50
# 448/448 [==============================] - 53s 119ms/step - loss: 0.3735 - accuracy: 0.8646 - val_loss: 1.2213 - val_accuracy: 0.6217

# %%
import matplotlib.pyplot as plt

# Get the training history
train_loss = emotion_model_info.history['loss']
train_accuracy = emotion_model_info.history['accuracy']
val_loss = emotion_model_info.history['val_loss']
val_accuracy = emotion_model_info.history['val_accuracy']
epochs = range(1, len(train_loss) + 1)

# Plot training and validation loss
plt.figure(figsize=(10, 5))
plt.plot(epochs, train_loss, label='Training Loss')
plt.plot(epochs, val_loss, label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()

# Plot training and validation accuracy
plt.figure(figsize=(10, 5))
plt.plot(epochs, train_accuracy, label='Training Accuracy')
plt.plot(epochs, val_accuracy, label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)
plt.show()
