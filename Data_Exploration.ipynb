# %%
import pandas as pd
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules

# %%
data = pd.read_csv("Final Year Project Survey (Responses) - Form Responses 1.csv")

# %%
q1_text = data['What specific factors do you believe influence emotional well-being in your workplace? Please elaborate.'].dropna().to_string(index=False)

wordcloud = WordCloud(width=800, height=400, background_color='white').generate(q1_text)

plt.figure(figsize=(10, 6))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
q2_text = data['How do you currently perceive the effectiveness of technology in understanding and addressing emotional shifts at your workplace? Provide examples if possible.'].dropna().to_string(index=False)
wordcloud2 = WordCloud(width=800, height=400, background_color='white').generate(q2_text)

plt.figure(figsize=(10, 6))
plt.imshow(wordcloud2, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
q3_text = data['In your opinion, what improvements or features would you like to see in a technology designed to monitor emotional well-being in the workplace?'].dropna().to_string(index=False)

wordcloud3 = WordCloud(width=800, height=400, background_color='white').generate(q2_text)

plt.figure(figsize=(10, 6))
plt.imshow(wordcloud3, interpolation='bilinear')
plt.axis('off')
plt.show()
